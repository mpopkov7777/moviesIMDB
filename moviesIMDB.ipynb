# %%
import os 
import matplotlib.pyplot as plt
import pandas as pd

os.path.isfile("/Users/markpopkov/Desktop/moviesIMDB.xls")

excelFile = "/Users/markpopkov/Desktop/moviesIMDB.xls"

movies_sheet3 = pd.read_excel(excelFile, sheetname=2, index_col=0)

movies_sheet3.head(10)
# Out:
#                                         Year  \
# Title
# 127 Hours                             2010.0
# 3 Backyards                           2010.0
# 3                                     2010.0
# 8: The Mormon Proposition             2010.0
# A Turtle's Tale: Sammy's Adventures   2010.0
# Alice in Wonderland                   2010.0
# Alice in Wonderland                   2010.0
# All Good Things                       2010.0
# Alpha and Omega                       2010.0
# Amigo                                 2010.0
#
#                                                                          Genres  \
# Title
# 127 Hours                                    Adventure|Biography|Drama|Thriller
# 3 Backyards                                                               Drama
# 3                                                          Comedy|Drama|Romance
# 8: The Mormon Proposition                                           Documentary
# ...

# %%
movies.describe()
 
movies['IMDB Score'].plot(kind="hist")
plt.show()

# %%
movies_by_gross = movies_sheet3.sort_values('Gross Earnings', ascending=False)

movies_by_gross.head(10)
# Out:
#                                     Year  \
# Title
# Jurassic World                    2015.0
# The Avengers                      2012.0
# The Avengers                      2012.0
# Avengers: Age of Ultron           2015.0
# The Dark Knight Rises             2012.0
# The Hunger Games: Catching Fire   2013.0
# Toy Story 3                       2010.0
# Iron Man 3                        2013.0
# The Hunger Games                  2012.0
# Captain America: Civil War        2016.0
#
#                                                                      Genres  \
# Title
# Jurassic World                             Action|Adventure|Sci-Fi|Thriller
# The Avengers                                        Action|Adventure|Sci-Fi
# The Avengers                                        Action|Adventure|Sci-Fi
# Avengers: Age of Ultron                             Action|Adventure|Sci-Fi
# The Dark Knight Rises                                       Action|Thriller
# ...

# %%
movies_by_gross['Gross Earnings'].mean()
# Out:
# 57806765.17467249

# %%
movies_by_score = movies_sheet3.sort_values('IMDB Score', ascending=False)

movies_by_score.head(10)
# Out:
#                                                   Year  \
# Title
# Towering Inferno                                   NaN
# Kickboxer: Vengeance                            2016.0
# Dekalog                                            NaN
# Dekalog                                            NaN
# Fargo                                              NaN
# It's Always Sunny in Philadelphia                  NaN
# Inception                                       2010.0
# Daredevil                                          NaN
# Gomorrah                                           NaN
# Friday Night Lights                                NaN
#
#                                                                                       Genres  \
# Title
# Towering Inferno                                                                      Comedy
# Kickboxer: Vengeance                                                                  Action
# ...
